# %%
# add this to check if the files are in the right place


if os.path.exists(home + 'data/streamlit_data/team_playtypes/isolation_offense' + today + '.csv'):
    st.write('Iso Offense Data is available for today')
else:
    st.write('Iso Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/isolation_defense' + today + '.csv'):
    st.write('Iso Defense Data is available for today')
else:
    st.write('Iso Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/postup_offense' + today + '.csv'):
    st.write('Post Up Offense Data is available for today')
else:
    st.write('Post Up Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/postup_defense' + today + '.csv'):
    st.write('Post Up Defense Data is available for today')
else:
    st.write('Post Up Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/prb_offense' + today + '.csv'):
    st.write('PRB Offense Data is available for today')
else:
    st.write('PRB Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/prb_defense' + today + '.csv'):
    st.write('PRB Defense Data is available for today')
else:
    st.write('PRB Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/pnr_offense' + today + '.csv'):
    st.write('PNR Offense Data is available for today')
else:
    st.write('PNR Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/pnr_defense' + today + '.csv'):
    st.write('PNR Defense Data is available for today')
else:
    st.write('PNR Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/spotup_offense' + today + '.csv'):
    st.write('Spot Up Offense Data is available for today')
else:
    st.write('Spot Up Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/spotup_defense' + today + '.csv'):
    st.write('Spot Up Defense Data is available for today')
else:
    st.write('Spot Up Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/handoff_offense' + today + '.csv'):
    st.write('Hand Off Offense Data is available for today')
else:
    st.write('Hand Off Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/handoff_defense' + today + '.csv'):
    st.write('Hand Off Defense Data is available for today')
else:
    st.write('Hand Off Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/cut_offense' + today + '.csv'):
    st.write('Cut Offense Data is available for today')
else:
    st.write('Cut Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/cut_defense' + today + '.csv'):
    st.write('Cut Defense Data is available for today')
else:
    st.write('Cut Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/offscreen_offense' + today + '.csv'):
    st.write('Off Screen Offense Data is available for today')
else:
    st.write('Off Screen Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/offscreen_defense' + today + '.csv'):
    st.write('Off Screen Defense Data is available for today')
else:
    st.write('Off Screen Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/transition_offense' + today + '.csv'):
    st.write('Transition Offense Data is available for today')
else:
    st.write('Transition Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/transition_defense' + today + '.csv'):
    st.write('Transition Defense Data is available for today')
else:
    st.write('Transition Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/putbacks_offense' + today + '.csv'):
    st.write('Putbacks Offense Data is available for today')
else:
    st.write('Putbacks Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/putbacks_defense' + today + '.csv'):
    st.write('Putbacks Defense Data is available for today')
else:
    st.write('Putbacks Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/paint_touches_offense' + today + '.csv'):
    st.write('Paint Touches Offense Data is available for today')
else:
    st.write('Paint Touches Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/paint_touches_defense' + today + '.csv'):
    st.write('Paint Touches Defense Data is available for today')
else:
    st.write('Paint Touches Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/penetration_offense' + today + '.csv'):
    st.write('Penetration Offense Data is available for today')
else:
    st.write('Penetration Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/penetration_defense' + today + '.csv'):
    st.write('Penetration Defense Data is available for today')
else:
    st.write('Penetration Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/isolation_offense' + today + '.csv'):
    st.write('Isolation Offense Data is available for today')
else:
    st.write('Isolation Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/isolation_defense' + today + '.csv'):
    st.write('Isolation Defense Data is available for today')
else:
    st.write('Isolation Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/postup_offense' + today + '.csv'):
    st.write('Post Up Offense Data is available for today')
else:
    st.write('Post Up Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/postup_defense' + today + '.csv'):
    st.write('Post Up Defense Data is available for today')
else:
    st.write('Post Up Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/prb_offense' + today + '.csv'):
    st.write('PRB Offense Data is available for today')
else:
    st.write('PRB Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/prb_defense' + today + '.csv'):
    st.write('PRB Defense Data is available for today')
else:
    st.write('PRB Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/pullup_offense' + today + '.csv'):
    st.write('Pull Up Offense Data is available for today')
else:
    st.write('Pull Up Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/pullup_defense' + today + '.csv'):
    st.write('Pull Up Defense Data is available for today')
else:
    st.write('Pull Up Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/spots_up_offense' + today + '.csv'):
    st.write('Spots Up Offense Data is available for today')
else:
    st.write('Spots Up Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/spots_up_defense' + today + '.csv'):
    st.write('Spots Up Defense Data is available for today')
else:
    st.write('Spots Up Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/handoff_offense' + today + '.csv'):
    st.write('Handoff Offense Data is available for today')
else:
    st.write('Handoff Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/handoff_defense' + today + '.csv'):
    st.write('Handoff Defense Data is available for today')
else:
    st.write('Handoff Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/cut_offense' + today + '.csv'):
    st.write('Cut Offense Data is available for today')
else:
    st.write('Cut Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/cut_defense' + today + '.csv'):
    st.write('Cut Defense Data is available for today')
else:
    st.write('Cut Defense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/offscreens_offense' + today + '.csv'):
    st.write('Off Screens Offense Data is available for today')
else:
    st.write('Off Screens Offense Data is NOT AVAILABLE for today')

if os.path.exists(home + 'data/streamlit_data/team_playtypes/offscreens_defense' + today + '.csv'):
    st.write('Off Screens Defense Data is available for today')
else:
    st.write('Off Screens Defense Data is NOT AVAILABLE for today')
